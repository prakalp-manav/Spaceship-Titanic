# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('train.csv')

# %%
data
# Out:
#      PassengerId HomePlanet CryoSleep     Cabin    Destination   Age    VIP  \
# 0        0001_01     Europa     False     B/0/P    TRAPPIST-1e  39.0  False
# 1        0002_01      Earth     False     F/0/S    TRAPPIST-1e  24.0  False
# 2        0003_01     Europa     False     A/0/S    TRAPPIST-1e  58.0   True
# 3        0003_02     Europa     False     A/0/S    TRAPPIST-1e  33.0  False
# 4        0004_01      Earth     False     F/1/S    TRAPPIST-1e  16.0  False
# ...          ...        ...       ...       ...            ...   ...    ...
# 8688     9276_01     Europa     False    A/98/P    55 Cancri e  41.0   True
# 8689     9278_01      Earth      True  G/1499/S  PSO J318.5-22  18.0  False
# 8690     9279_01      Earth     False  G/1500/S    TRAPPIST-1e  26.0  False
# 8691     9280_01     Europa     False   E/608/S    55 Cancri e  32.0  False
# 8692     9280_02     Europa     False   E/608/S    TRAPPIST-1e  44.0  False
#
# ...

# %%
data.drop(2,axis=0)
# Out:
#      PassengerId HomePlanet CryoSleep     Cabin    Destination   Age    VIP  \
# 0        0001_01     Europa     False     B/0/P    TRAPPIST-1e  39.0  False
# 1        0002_01      Earth     False     F/0/S    TRAPPIST-1e  24.0  False
# 3        0003_02     Europa     False     A/0/S    TRAPPIST-1e  33.0  False
# 4        0004_01      Earth     False     F/1/S    TRAPPIST-1e  16.0  False
# 5        0005_01      Earth     False     F/0/P  PSO J318.5-22  44.0  False
# ...          ...        ...       ...       ...            ...   ...    ...
# 8688     9276_01     Europa     False    A/98/P    55 Cancri e  41.0   True
# 8689     9278_01      Earth      True  G/1499/S  PSO J318.5-22  18.0  False
# 8690     9279_01      Earth     False  G/1500/S    TRAPPIST-1e  26.0  False
# 8691     9280_01     Europa     False   E/608/S    55 Cancri e  32.0  False
# 8692     9280_02     Europa     False   E/608/S    TRAPPIST-1e  44.0  False
#
# ...

# %%
data.isnull().sum()
# Out:
# PassengerId       0
# HomePlanet      201
# CryoSleep       217
# Cabin           199
# Destination     182
# Age             179
# VIP             203
# RoomService     181
# FoodCourt       183
# ShoppingMall    208
# Spa             183
# VRDeck          188
# Name            200
# Transported       0
# dtype: int64

# %%
data = data.dropna()

# %%
data.isnull().sum()
# Out:
# PassengerId     0
# HomePlanet      0
# CryoSleep       0
# Cabin           0
# Destination     0
# Age             0
# VIP             0
# RoomService     0
# FoodCourt       0
# ShoppingMall    0
# Spa             0
# VRDeck          0
# Name            0
# Transported     0
# dtype: int64

# %%
data['Destination'].unique()
# Out:
# array(['TRAPPIST-1e', 'PSO J318.5-22', '55 Cancri e'], dtype=object)

# %%
temp = {'TRAPPIST-1e':1, 'PSO J318.5-22':2, '55 Cancri e':3}

# %%
data['Destination'] = data['Destination'].map(temp)
# Out:
# C:\Users\ratee\AppData\Local\Temp\ipykernel_15472\3755750958.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Destination'] = data['Destination'].map(temp)

# %%
data
# Out:
#      PassengerId HomePlanet CryoSleep     Cabin  Destination   Age    VIP  \
# 0        0001_01     Europa     False     B/0/P            1  39.0  False
# 1        0002_01      Earth     False     F/0/S            1  24.0  False
# 2        0003_01     Europa     False     A/0/S            1  58.0   True
# 3        0003_02     Europa     False     A/0/S            1  33.0  False
# 4        0004_01      Earth     False     F/1/S            1  16.0  False
# ...          ...        ...       ...       ...          ...   ...    ...
# 8688     9276_01     Europa     False    A/98/P            3  41.0   True
# 8689     9278_01      Earth      True  G/1499/S            2  18.0  False
# 8690     9279_01      Earth     False  G/1500/S            1  26.0  False
# 8691     9280_01     Europa     False   E/608/S            3  32.0  False
# 8692     9280_02     Europa     False   E/608/S            1  44.0  False
#
#       RoomService  FoodCourt  ShoppingMall     Spa  VRDeck               Name  \
# ...

# %%
data['HomePlanet'].unique()
# Out:
# array(['Europa', 'Earth', 'Mars'], dtype=object)

# %%
temp = {'Europa':1,'Earth':2,'Mars':3}

data['HomePlanet'] = data['HomePlanet'].map(temp)
# Out:
# C:\Users\ratee\AppData\Local\Temp\ipykernel_15472\3142955017.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['HomePlanet'] = data['HomePlanet'].map(temp)

# %%
data
# Out:
#      PassengerId  HomePlanet CryoSleep     Cabin  Destination   Age    VIP  \
# 0        0001_01           1     False     B/0/P            1  39.0  False
# 1        0002_01           2     False     F/0/S            1  24.0  False
# 2        0003_01           1     False     A/0/S            1  58.0   True
# 3        0003_02           1     False     A/0/S            1  33.0  False
# 4        0004_01           2     False     F/1/S            1  16.0  False
# ...          ...         ...       ...       ...          ...   ...    ...
# 8688     9276_01           1     False    A/98/P            3  41.0   True
# 8689     9278_01           2      True  G/1499/S            2  18.0  False
# 8690     9279_01           2     False  G/1500/S            1  26.0  False
# 8691     9280_01           1     False   E/608/S            3  32.0  False
# 8692     9280_02           1     False   E/608/S            1  44.0  False
#
# ...

# %%
extra = pd.DataFrame(list(data['Cabin'].str.split('/')))

# %%
extra[0].unique()
# Out:
# array(['B', 'F', 'A', 'G', 'E', 'C', 'D', 'T'], dtype=object)

# %%
data['Comp'] = extra[0]
# Out:
# C:\Users\ratee\AppData\Local\Temp\ipykernel_15472\1629020753.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Comp'] = extra[0]

# %%
data = data.drop('Name',axis=1)

# %%
data
# Out:
#      PassengerId  HomePlanet CryoSleep     Cabin  Destination   Age    VIP  \
# 0        0001_01           1     False     B/0/P            1  39.0  False
# 1        0002_01           2     False     F/0/S            1  24.0  False
# 2        0003_01           1     False     A/0/S            1  58.0   True
# 3        0003_02           1     False     A/0/S            1  33.0  False
# 4        0004_01           2     False     F/1/S            1  16.0  False
# ...          ...         ...       ...       ...          ...   ...    ...
# 8688     9276_01           1     False    A/98/P            3  41.0   True
# 8689     9278_01           2      True  G/1499/S            2  18.0  False
# 8690     9279_01           2     False  G/1500/S            1  26.0  False
# 8691     9280_01           1     False   E/608/S            3  32.0  False
# 8692     9280_02           1     False   E/608/S            1  44.0  False
#
# ...

# %%
np.array(data['Cabin'].str.split('/'))
# Out:
# array([list(['B', '0', 'P']), list(['F', '0', 'S']),
#        list(['A', '0', 'S']), ..., list(['G', '1500', 'S']),
#        list(['E', '608', 'S']), list(['E', '608', 'S'])], dtype=object)

# %%
data['Comp'] = pd.DataFrame(extra[0])

# %%
data
# Out:
#      PassengerId  HomePlanet CryoSleep     Cabin  Destination   Age    VIP  \
# 0        0001_01           1     False     B/0/P            1  39.0  False
# 1        0002_01           2     False     F/0/S            1  24.0  False
# 2        0003_01           1     False     A/0/S            1  58.0   True
# 3        0003_02           1     False     A/0/S            1  33.0  False
# 4        0004_01           2     False     F/1/S            1  16.0  False
# ...          ...         ...       ...       ...          ...   ...    ...
# 8688     9276_01           1     False    A/98/P            3  41.0   True
# 8689     9278_01           2      True  G/1499/S            2  18.0  False
# 8690     9279_01           2     False  G/1500/S            1  26.0  False
# 8691     9280_01           1     False   E/608/S            3  32.0  False
# 8692     9280_02           1     False   E/608/S            1  44.0  False
#
# ...

# %%
def func(strr):
    temp = list(strr.split('/'))
    return temp[0]

# %%
data['Comp'] = data['Cabin'].apply(func)

# %%
def func(strr):
    temp = list(strr.split('/'))
    return temp[2]

# %%
data['Cde'] = data['Cabin'].apply(func)

# %%
data
# Out:
#      PassengerId  HomePlanet CryoSleep     Cabin  Destination   Age    VIP  \
# 0        0001_01           1     False     B/0/P            1  39.0  False
# 1        0002_01           2     False     F/0/S            1  24.0  False
# 2        0003_01           1     False     A/0/S            1  58.0   True
# 3        0003_02           1     False     A/0/S            1  33.0  False
# 4        0004_01           2     False     F/1/S            1  16.0  False
# ...          ...         ...       ...       ...          ...   ...    ...
# 8688     9276_01           1     False    A/98/P            3  41.0   True
# 8689     9278_01           2      True  G/1499/S            2  18.0  False
# 8690     9279_01           2     False  G/1500/S            1  26.0  False
# 8691     9280_01           1     False   E/608/S            3  32.0  False
# 8692     9280_02           1     False   E/608/S            1  44.0  False
#
# ...

# %%
temp = {'P':True,'S':False}

data['Cde'] = data['Cde'].map(temp)

# %%
data = data.drop('Cabin',axis=1)

# %%
data = data.drop('PassengerId',axis=1)

# %%
temp = {'B':1, 'F':2, 'A':3, 'G':4, 'E':5, 'C':6, 'D':7, 'T':8}

data['Comp'] = data['Comp'].map(temp)

# %%
data
# Out:
# c:\Users\ratee\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\lib\pretty.py:778: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   output = repr(obj)
# c:\Users\ratee\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\formatters.py:342: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   return method()
#       HomePlanet CryoSleep  Destination   Age    VIP  RoomService  FoodCourt  \
# 0              1     False            1  39.0  False          0.0        0.0
# 1              2     False            1  24.0  False        109.0        9.0
# 2              1     False            1  58.0   True         43.0     3576.0
# 3              1     False            1  33.0  False          0.0     1283.0
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(data.corr(),annot=True)
# Out:
# C:\Users\ratee\AppData\Local\Temp\ipykernel_15472\3772768352.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(),annot=True)
# <AxesSubplot: >

# %%
data.drop('Age',axis=1,inplace=True)
data
# Out:
# c:\Users\ratee\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\lib\pretty.py:778: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   output = repr(obj)
# c:\Users\ratee\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\formatters.py:342: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   return method()
#       HomePlanet CryoSleep  Destination    VIP  RoomService  FoodCourt  \
# 0              1     False            1  False          0.0        0.0
# 1              2     False            1  False        109.0        9.0
# 2              1     False            1   True         43.0     3576.0
# 3              1     False            1  False          0.0     1283.0
# ...

# %%
data.drop('FoodCourt',axis=1,inplace=True)
data
# Out:
# c:\Users\ratee\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\lib\pretty.py:778: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   output = repr(obj)
# c:\Users\ratee\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\formatters.py:342: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   return method()
#       HomePlanet CryoSleep  Destination    VIP  RoomService  ShoppingMall  \
# 0              1     False            1  False          0.0           0.0
# 1              2     False            1  False        109.0          25.0
# 2              1     False            1   True         43.0           0.0
# 3              1     False            1  False          0.0         371.0
# ...

# %%
data.drop('ShoppingMall',axis=1,inplace=True)
data
# Out:
# c:\Users\ratee\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\lib\pretty.py:778: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   output = repr(obj)
# c:\Users\ratee\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\formatters.py:342: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   return method()
#       HomePlanet CryoSleep  Destination    VIP  RoomService     Spa  VRDeck  \
# 0              1     False            1  False          0.0     0.0     0.0
# 1              2     False            1  False        109.0   549.0    44.0
# 2              1     False            1   True         43.0  6715.0    49.0
# 3              1     False            1  False          0.0  3329.0   193.0
# ...

# %%
data.drop('Comp',axis=1,inplace=True)
data
# Out:
# c:\Users\ratee\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\lib\pretty.py:778: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   output = repr(obj)
# c:\Users\ratee\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\formatters.py:342: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   return method()
#       HomePlanet CryoSleep  Destination    VIP  RoomService     Spa  VRDeck  \
# 0              1     False            1  False          0.0     0.0     0.0
# 1              2     False            1  False        109.0   549.0    44.0
# 2              1     False            1   True         43.0  6715.0    49.0
# 3              1     False            1  False          0.0  3329.0   193.0
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(data.corr(),annot=True)
# Out:
# C:\Users\ratee\AppData\Local\Temp\ipykernel_15472\3772768352.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(),annot=True)
# <AxesSubplot: >

# %%
data
# Out:
# c:\Users\ratee\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\lib\pretty.py:778: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   output = repr(obj)
# c:\Users\ratee\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\formatters.py:342: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   return method()
#       HomePlanet CryoSleep  Destination    VIP  RoomService     Spa  VRDeck  \
# 0              1     False            1  False          0.0     0.0     0.0
# 1              2     False            1  False        109.0   549.0    44.0
# 2              1     False            1   True         43.0  6715.0    49.0
# 3              1     False            1  False          0.0  3329.0   193.0
# ...

# %%
from xgboost import XGBClassifier

# %%
from sklearn.model_selection import train_test_split

# %%
np.random.seed(42)
X_train,X_test,Y_train,Y_test = train_test_split(data.drop('Transported',axis=1),data['Transported'],test_size = 0.3)

# %%
model = XGBClassifier()

# %%
data.dtypes
# Out:
# HomePlanet       int64
# CryoSleep       object
# Destination      int64
# VIP             object
# RoomService    float64
# Spa            float64
# VRDeck         float64
# Transported       bool
# Cde               bool
# dtype: object

# %%
data['VIP'] = data['VIP'].astype(bool)
data['CryoSleep'] = data['CryoSleep'].astype(bool)

# %%
data
# Out:
#       HomePlanet  CryoSleep  Destination    VIP  RoomService     Spa  VRDeck  \
# 0              1      False            1  False          0.0     0.0     0.0
# 1              2      False            1  False        109.0   549.0    44.0
# 2              1      False            1   True         43.0  6715.0    49.0
# 3              1      False            1  False          0.0  3329.0   193.0
# 4              2      False            1  False        303.0   565.0     2.0
# ...          ...        ...          ...    ...          ...     ...     ...
# 8688           1      False            3   True          0.0  1643.0    74.0
# 8689           2       True            2  False          0.0     0.0     0.0
# 8690           2      False            1  False          0.0     1.0     0.0
# 8691           1      False            3  False          0.0   353.0  3235.0
# 8692           1      False            1  False        126.0     0.0    12.0
#
#       Transported    Cde
# ...

# %%
data.dtypes
# Out:
# HomePlanet       int64
# CryoSleep         bool
# Destination      int64
# VIP               bool
# RoomService    float64
# Spa            float64
# VRDeck         float64
# Transported       bool
# Cde               bool
# dtype: object

# %%
data
# Out:
#       HomePlanet  CryoSleep  Destination    VIP  RoomService     Spa  VRDeck  \
# 0              1      False            1  False          0.0     0.0     0.0
# 1              2      False            1  False        109.0   549.0    44.0
# 2              1      False            1   True         43.0  6715.0    49.0
# 3              1      False            1  False          0.0  3329.0   193.0
# 4              2      False            1  False        303.0   565.0     2.0
# ...          ...        ...          ...    ...          ...     ...     ...
# 8688           1      False            3   True          0.0  1643.0    74.0
# 8689           2       True            2  False          0.0     0.0     0.0
# 8690           2      False            1  False          0.0     1.0     0.0
# 8691           1      False            3  False          0.0   353.0  3235.0
# 8692           1      False            1  False        126.0     0.0    12.0
#
#       Transported    Cde
# ...

# %%
np.random.seed(42)
X_train,X_test,Y_train,Y_test = train_test_split(data.drop('Transported',axis=1),data['Transported'],test_size = 0.3)
model.fit(X_train,Y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)

# %%
model.score(X_test,Y_test)
# Out:
# 0.7729566094853683

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
mdl = RandomForestClassifier()

# %%
mdl.fit(X_train,Y_train)
# Out:
# RandomForestClassifier()

# %%
mdl.score(X_test,Y_test)
# Out:
# 0.7714429868819375

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(X_train,Y_train)
# Out:
# c:\Users\ratee\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
model.score(X_test,Y_test)
# Out:
# 0.7759838546922301

# %%
model = LogisticRegression()

# %%
model.fit(data.drop('Transported',axis=1),data['Transported'])
# Out:
# c:\Users\ratee\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
test = pd.read_csv('test.csv')

# %%
test.drop('Age',axis=1,inplace=True)

# %%
test
# Out:
#      HomePlanet CryoSleep     Cabin    Destination    VIP  RoomService  \
# 0         Earth      True     G/3/S    TRAPPIST-1e  False          0.0
# 1         Earth     False     F/4/S    TRAPPIST-1e  False          0.0
# 2        Europa      True     C/0/S    55 Cancri e  False          0.0
# 3        Europa     False     C/1/S    TRAPPIST-1e  False          0.0
# 4         Earth     False     F/5/S    TRAPPIST-1e  False         10.0
# ...         ...       ...       ...            ...    ...          ...
# 4272      Earth      True  G/1496/S    TRAPPIST-1e  False          0.0
# 4273      Earth     False       NaN    TRAPPIST-1e  False          0.0
# 4274       Mars      True   D/296/P    55 Cancri e  False          0.0
# 4275     Europa     False   D/297/P            NaN  False          0.0
# 4276      Earth      True  G/1498/S  PSO J318.5-22  False          0.0
#
#          Spa  VRDeck
# 0        0.0     0.0
# 1     2823.0     0.0
# 2        0.0     0.0
# 3      181.0   585.0
# ...

# %%
data
# Out:
#       HomePlanet  CryoSleep  Destination    VIP  RoomService     Spa  VRDeck  \
# 0              1      False            1  False          0.0     0.0     0.0
# 1              2      False            1  False        109.0   549.0    44.0
# 2              1      False            1   True         43.0  6715.0    49.0
# 3              1      False            1  False          0.0  3329.0   193.0
# 4              2      False            1  False        303.0   565.0     2.0
# ...          ...        ...          ...    ...          ...     ...     ...
# 8688           1      False            3   True          0.0  1643.0    74.0
# 8689           2       True            2  False          0.0     0.0     0.0
# 8690           2      False            1  False          0.0     1.0     0.0
# 8691           1      False            3  False          0.0   353.0  3235.0
# 8692           1      False            1  False        126.0     0.0    12.0
#
#       Transported    Cde
# ...

# %%
test['HomePlanet'] = test['HomePlanet'].fillna('Earth')

# %%
test.isnull().sum()
# Out:
# HomePlanet       0
# CryoSleep       93
# Cabin          100
# Destination     92
# VIP             93
# RoomService     82
# Spa            101
# VRDeck          80
# dtype: int64

# %%
temp = {'Europa':1,'Earth':2,'Mars':3}

# %%
test['HomePlanet'] = test['HomePlanet'].map(temp)

# %%
test
# Out:
#       HomePlanet CryoSleep     Cabin    Destination    VIP  RoomService  \
# 0              2      True     G/3/S    TRAPPIST-1e  False          0.0
# 1              2     False     F/4/S    TRAPPIST-1e  False          0.0
# 2              1      True     C/0/S    55 Cancri e  False          0.0
# 3              1     False     C/1/S    TRAPPIST-1e  False          0.0
# 4              2     False     F/5/S    TRAPPIST-1e  False         10.0
# ...          ...       ...       ...            ...    ...          ...
# 4272           2      True  G/1496/S    TRAPPIST-1e  False          0.0
# 4273           2     False       NaN    TRAPPIST-1e  False          0.0
# 4274           3      True   D/296/P    55 Cancri e  False          0.0
# 4275           1     False   D/297/P            NaN  False          0.0
# 4276           2      True  G/1498/S  PSO J318.5-22  False          0.0
#
#          Spa  VRDeck
# 0        0.0     0.0
# 1     2823.0     0.0
# 2        0.0     0.0
# ...

# %%
ex = pd.DataFrame(test['Cabin'].str.split('/',expand=True)[2])

# %%
ex = ex.fillna('S')

# %%
temp = {'P':True,'S':False}

test['Cde'] = ex

# %%
test
# Out:
#       HomePlanet CryoSleep     Cabin    Destination    VIP  RoomService  \
# 0              2      True     G/3/S    TRAPPIST-1e  False          0.0
# 1              2     False     F/4/S    TRAPPIST-1e  False          0.0
# 2              1      True     C/0/S    55 Cancri e  False          0.0
# 3              1     False     C/1/S    TRAPPIST-1e  False          0.0
# 4              2     False     F/5/S    TRAPPIST-1e  False         10.0
# ...          ...       ...       ...            ...    ...          ...
# 4272           2      True  G/1496/S    TRAPPIST-1e  False          0.0
# 4273           2     False       NaN    TRAPPIST-1e  False          0.0
# 4274           3      True   D/296/P    55 Cancri e  False          0.0
# 4275           1     False   D/297/P            NaN  False          0.0
# 4276           2      True  G/1498/S  PSO J318.5-22  False          0.0
#
#          Spa  VRDeck Cde
# 0        0.0     0.0   S
# 1     2823.0     0.0   S
# ...

# %%
test['Cde'] = test['Cde'].map(temp)

# %%
test.drop('Cabin',axis=1,inplace=True)

# %%
test
# Out:
#       HomePlanet CryoSleep    Destination    VIP  RoomService     Spa  VRDeck  \
# 0              2      True    TRAPPIST-1e  False          0.0     0.0     0.0
# 1              2     False    TRAPPIST-1e  False          0.0  2823.0     0.0
# 2              1      True    55 Cancri e  False          0.0     0.0     0.0
# 3              1     False    TRAPPIST-1e  False          0.0   181.0   585.0
# 4              2     False    TRAPPIST-1e  False         10.0     0.0     0.0
# ...          ...       ...            ...    ...          ...     ...     ...
# 4272           2      True    TRAPPIST-1e  False          0.0     0.0     0.0
# 4273           2     False    TRAPPIST-1e  False          0.0    10.0   144.0
# 4274           3      True    55 Cancri e  False          0.0     0.0     0.0
# 4275           1     False            NaN  False          0.0     0.0   523.0
# 4276           2      True  PSO J318.5-22  False          0.0     0.0     0.0
#
#         Cde
# 0     False
# ...

# %%
temp = {'TRAPPIST-1e':1, 'PSO J318.5-22':2, '55 Cancri e':3}

# %%
test['Destination'] = test['Destination'].fillna('TRAPPIST-1e')

# %%
test
# Out:
# c:\Users\ratee\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\lib\pretty.py:778: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   output = repr(obj)
# c:\Users\ratee\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\formatters.py:342: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   return method()
#       HomePlanet CryoSleep    Destination    VIP  RoomService     Spa  VRDeck  \
# 0              2      True    TRAPPIST-1e  False          0.0     0.0     0.0
# 1              2     False    TRAPPIST-1e  False          0.0  2823.0     0.0
# 2              1      True    55 Cancri e  False          0.0     0.0     0.0
# ...

# %%
test['Destination'] = test['Destination'].map(temp)

# %%
test
# Out:
# c:\Users\ratee\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\lib\pretty.py:778: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   output = repr(obj)
# c:\Users\ratee\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\formatters.py:342: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   return method()
#       HomePlanet CryoSleep  Destination    VIP  RoomService     Spa  VRDeck  \
# 0              2      True            1  False          0.0     0.0     0.0
# 1              2     False            1  False          0.0  2823.0     0.0
# 2              1      True            3  False          0.0     0.0     0.0
# 3              1     False            1  False          0.0   181.0   585.0
# ...

# %%
test['CryoSleep'] = test['CryoSleep'].fillna(False)

# %%
test['VIP'] = test['VIP'].fillna(False)

# %%
test.isnull().sum()
# Out:
# HomePlanet     0
# CryoSleep      0
# Destination    0
# VIP            0
# RoomService    0
# Spa            0
# VRDeck         0
# Cde            0
# dtype: int64

# %%
test['VRDeck'] = test['VRDeck'].fillna(0)

# %%
ans = pd.DataFrame(model.predict(test),columns=['Transported'])

# %%
ans
# Out:
#       Transported
# 0            True
# 1           False
# 2            True
# 3           False
# 4            True
# ...           ...
# 4272         True
# 4273         True
# 4274         True
# 4275        False
# 4276         True
#
# [4277 rows x 1 columns]

# %%
tee = pd.read_csv('test.csv')

# %%
ans['PassengerId'] = tee['PassengerId']

# %%
ans['Transported'] = ans['Transported']

# %%
ans.columns = ans.columns[::-1]

# %%
ans['PassengerId'] = ans['Transported']

# %%
ans['Transported'] = model.predict(test)

# %%
ans.to_csv('ans.csv',index=False)
